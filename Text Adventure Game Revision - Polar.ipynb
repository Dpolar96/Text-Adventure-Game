# %%
# Text Adventure Game
#Diego Alonso Polar Velasquez
#Original inspiration source for the Text Game
'''----------------------------------
Source: 
Wikipedia. (n.d.). Nineteen Eighty-Four. Retrieved January 27, 2022, 
from https://en.wikipedia.org/wiki/Nineteen_Eighty-Four
-------------------------------------'''
#List of bugs encountered during the coding.
'''
Bugs:
- Inserting an invalid output or blank space will take you to the beginning of the stage
instead of the previous choice.
- Due to the text and numbers being classified as string, it only recognizes the first character, 
disregarding any combination.
- Use of case control methods on any choices makes the code not recognize the proper input.
'''

def intro_instructions (): #Initial docstring including a short introduction of the story.
    print('''You are Winston, a member of The Party working in one of their factories, 
    you’ve recently met Julia and together you have the joined the Brotherhood to 
    take down Big Brother and improve your own living standards. You still have 
    your own doubts about the Brotherhood and your mysterious contact O’Brien, 
    but you haven’t felt more alive in ages and can’t resist Julia’s charms.\n''') 
    #Wikipedia source for the book to give a quick overview of what the book is about.
    print('''Join Winston and Julia in one of their escapades throughout the night to help 
    the supposed rebellion.\n''')
    input(prompt = "<Press any key to begin>\n") #Initial prompt to begin the game.
    stage_1()
    
def stage_1(): #Definition and beginning of stage 1.
    print('''It’s a Friday night, wet, damp, and the streets look dark and lonely. 
    You’ve received a message from O’Brien to pick up a package in between two 
    dumpsters and deliver it to the train station. Julia, your lover, is a block 
    ahead of you and is calling for you. “Winston, my love, hurry up we don’t much time to do this!”\n''')
    choice_1 = input(prompt = '''Three options come into your head: 
    1. You hurry up and join in picking the package and getting out.
    2. You tell Julia to lower her voice and that you are approaching.
    3. You decide this is too suspicious and go back home.\n''') #Initial prompt for user to choose what option he/she prefers.
    try: #Function looking for errors leading to ending the program.
        choice_1 = str(choice_1)        
        if '1' in choice_1:#Use of if functions to recognize the user inputs.
            print('You trip with a passing can and alert the whole neighborhood. The Thought police is approaching')
            fail() #Choosing an incorrect option will take you directly to the fail condition.
        elif '2' in choice_1:
            print('You tell Julia to lower her voice and that you are approaching.\n') #End of choice 1.
            choice_2 = input(prompt = '''You reach the dumpster and find the package, but removing it alerts a passing 
                dog who starts barking at you. The neighbors are coming, and one asks who are you.
                Your options are:
                1. You act drunk and try to convince them that you and Julia are going back home.
                2. You turn around run as fast you can.
                3. You try to bribe the neighbors with some chocolate you have at hand.''') #New prompt for user to take a decision.
            try: #Function looking for errors leading to ending the program.
                choice_2 = str(choice_2)
                if '1' in choice_2: 
                        print('''The neighbors smile knowingly at Julia and tell her:
                        "Dear, take your husband home, Big Brother needs all his senses tomorrow."\n''') 
                        stage_2()#End of stage 1 and beginning of stage 2.
                elif '2' in choice_2:
                        print("But you can't outrun neither them or the nearby patrol they called.\n")
                        fail()
                elif '3' in choice_2:
                        print("The neighbors don’t recognize the brand and call the Thought police. ")
                        fail()
                else:
                        print('Invalid input, please try again.')
                        stage_1() #Any invalid inputs will automatically bring you back to the beginning of the stage.
            except: #Output of the previously defined try function leading to a termination of the program.  
                choice_2 = input(prompt = f'Invalid input, please try again.') 
        elif '3' in choice_1:
            print('But ran into a Thought police patrol who is passing by.')
            fail()      
        else:
            print('Invalid input, please try again.')
            stage_1()#Returning to the beginning of the stage.

    except: #Output of the previously defined try function leading to a termination of the program. 
        choice_1 = input(prompt = f'Invalid input, please try again.') 
        
def stage_2():
    print('''After getting rid of the prying neighbors, you and Julia continue 
    your task and manage to reach the train station, there are few people around, 
    but you don’t who is the contact, there are three suspicious individuals: 
    One clad in full Party-outfit, what it seems to be a Thought police agent, 
    and a random civilian wearing a fedora.\n''') #Introductory text to the stage.
    choice_3 = input(prompt = '''Who of those three might be the one:
    1. The Party fanatic,
    2. The probable agent or,
    3. The fedora-wearing fellow?\n''')#Choices available in the input statement.
    try: #Function looking for errors leading to ending the program.
        choice_3 = str(choice_3)
        if '1' in choice_3:
            print('You approach the Party fanatic and give him the package. He seems suspicious of you and calls the Thought police.\n')
            fail()#Choosing poorly will bring the game to an end.
        elif '2' in choice_3:
            print('You approach the agent and give him the package. He is an actual member of the Thought Police.\n')
            fail()
        elif '3' in choice_3: #End of choice 3.
            print('You approach the fedora wearing civilian and give him the package. He says thank you and gives you an envelope with a Goldstein logo.\n')
            choice_4 = input(prompt = '''After receiving the letter, you don’t know what to do with it, if to open it or deliver it to O’Brien. 
            Julia seems plenty curious about that letter and is reaching out for her letter opener to read it.
                Your options are:
                1. You stop Julia and tell her it’s a letter directed to O’Brien.
                2. You let her open the letter as you are plenty curious as well.
                3. You throw the letter to the nearby trash can.\n''')
            try: #Function looking for errors leading to ending the program.
                choice_4 = str(choice_4)
                if '1' in choice_4:
                        print('Julia relents on her attempt and nods in understanding.\n') 
                        stage_3() #End of choice 4 and beginning of stage 3.
                elif '2' in choice_4:
                        print("The letter hides a confetti bomb and a red piece of paper. You catch the attention of the nearby agent.\n")
                        fail()
                elif '3' in choice_4:
                        print("The agent seems puzzled by this behavior and ask you to join him to the station.\n")
                        fail()
                else:
                        print('Invalid input, please try again.\n')
                        stage_2()      
            except: #Output of the previously defined try function leading to a termination of the program.  
                choice_4 = input(prompt = f'Invalid input, please try again.') 
        else:
            print('Invalid input, please try again.\n')
            stage_2() #Invalid inputs will bring you to the beginning of the stage.
    except: #Output of the previously defined try function leading to a termination of the program.  
        choice_3 = input(prompt = f'Invalid input, please try again.') 

def stage_3():
    minutes = 3
    print('Getting away from the station, you go back in direction to your hideout.\n')
    random_event_1 = ['You step on a rock and alert the Thought Police.',
                     'You keep walking.',
                     'The officer gets distracted and walks to the side.']
    while minutes > 0: #Simple while loop to simulate passing of the time.
        input(prompt = '<Press any key 3 times to walk 3 minutes.>\n')
        minutes -= 1 
    print('You start hearing noises aside from the rain. Footsteps are approaching\n') #Beginning of choice 5.
    choice_5 = input(prompt ='''You are sure somebody is tailing you. You don't have time to think'.
    Two ideas come into your head.
    1. Keep walking and ignore your pursuer.
    2. Kiss Julia and see if that distracts him.\n''') 
    try: #Function looking for errors leading to ending the program.
        choice_5 = str(choice_5)
        if '1' in choice_5:
            print('It’s an agent from the Thought Police, he’s asking you for you to join him at the station.\n')
            fail()
        elif '2' in choice_5:
            print('People ignore you and the nearby agent just keeps walking.')
            stage_4()#End of choice 5 and beginning of stage 4.
        else:
            print('Invalid input, please try again.\n')
            stage_3()
    except:  #Output of the previously defined try function leading to a termination of the program. 
        choice_5 = input(prompt = f'Invalid input, please try again.') 

            
def stage_4():
    print('You reach O’Brien’s hideout and give him the letter, he asks if anybody was following you.\n')
    choice_6 = input(prompt = '''There are three thoughts regarding what you could say to O'Brien:
    1.You reply that yes but they were misled and escaped their sight.
    2.You say no and try to get home.
    3.You say “I love Big Brother”\n''') #Beginning of choice 6.
    try: #Function looking for errors leading to ending the program.
        choice_6 = str(choice_6)
        if '1' in choice_6:
            print('Wrapping the debrief with O’Brien you and Julia return to your apartment and try to call it a night.')
            choice_7 = input(prompt = '''You are weighing your options, whether to celebrate or get some 'rest'.
            1. There is a bottle of champagne you save on your counter. Could this be a good moment to open it?
            2. Or should you kiss Julia and see where it leads to.\n''')
            try: #Function looking for errors leading to ending the program.
                choice_7 = str(choice_7)
                if '1' in choice_7:
                    print('You open the champagne and its cork blows one of the lamps. The neighbors call in the Thought police.\n')
                    fail()
                elif '2' in choice_7:
                    win() #End of Stage 4 and achieving win condition.
                else:
                    print('Invalid input, please try again.\n')
                    stage_4()
            except: #Output of the previously defined try function leading to a termination of the program. 
                choice_7 = input(prompt = f'Invalid input, please try again.')
        elif '2' in choice_6:
            print('O’Brien stops you and tells you don’t have to lie. He reveals he is a Thought police agent and arrests you.\n')
        elif '3' in choice_6:
            print('O’Brien repeats the chant and reveals he is an undercover agent. You are arrested.\n')
            fail()
        else:
            print('Invalid input, please try again.\n')
            stage_4() #Invalid inputs will bring the user to repeat the stage.
    except: #Output of the previously defined try function leading to a termination of the program. 
        choice_6 = input(prompt = f'Invalid input, please try again.')
       
        
def win(): #Defining the win condition for the game.
    print("You and Julia spend a passionate night to celebrate your survival in the Big Brother controlled Oceania.\n")
    input(prompt = '<Press any key to exit>\n')#Any input will lead to the end of the program.

    
                      
def fail(): #Defining the fail condition for the game.
    print('''It’s determined by the Thought police that you have to attend a session 
    at the Ministry of Love. You emerge a changed man, knowing only one truth. 
    You love Big Brother.\n''')
    input(prompt = '<Press any key to exit>\n')#Any input will lead to the end of the program.
    
    
intro_instructions() #Don't delete this line as the code won't run without it.
# Out:
# You are Winston, a member of The Party working in one of their factories,
#     you’ve recently met Julia and together you have the joined the Brotherhood to
#     take down Big Brother and improve your own living standards. You still have
#     your own doubts about the Brotherhood and your mysterious contact O’Brien,
#     but you haven’t felt more alive in ages and can’t resist Julia’s charms.
#
# Join Winston and Julia in one of their escapades throughout the night to help
#     the supposed rebellion.
#
# <Press any key to begin>
# 2
# It’s a Friday night, wet, damp, and the streets look dark and lonely.
#     You’ve received a message from O’Brien to pick up a package in between two
#     dumpsters and deliver it to the train station. Julia, your lover, is a block
#     ahead of you and is calling for you. “Winston, my love, hurry up we don’t much time to do this!”
#
# Three options come into your head:
#     1. You hurry up and join in picking the package and getting out.
# ...
